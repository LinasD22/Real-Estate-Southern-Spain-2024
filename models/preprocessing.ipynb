# %% [markdown]
# # ML Preprocessing for Real Estate Southern Spain
#
# This notebook is for machine learning preprocessing tasks.

# %%
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import OneHotEncoder

# %%
# Load data
# Add your preprocessing code here

# %%
df = pd.read_csv('../data/properties.csv')
pd.set_option('display.float_format', '{:,.0f}'.format)
#pd.reset_option('display.float_format')
df_real = df.copy()
df.columns = df.columns.str.strip()

# %%
#df.head()#df.columns
ref = df['reference'].tolist()
df['reference'].unique()
# Out:
# array(['R126116', 'R132516', 'R121563', ..., 'R90252', 'R89424',
#        'R706006'], dtype=object)

# %%
df['price'] = (
    df['price']
    .astype(str)
    .str.replace(r'[^\d.,]', '', regex=True) 
    .str.replace(',', '')                     
    .astype(float)
)

df['features'] = (
    df['pipe-separed list of features of the property']
    .str.lower()
    .str.split('|')
)

df['property_type'] = (
    df['title']
    .str.replace(r'^\d+\s*Bedroom(s)?\s*', '', regex=True)
    .str.replace(r'^\d+\s*', '', regex=True)    
    .str.strip()
)

print(df['property_type'].unique())

df['y'] = np.log(df['price'])
df.describe()
# Out:
# ['Apartment' 'Other' 'Finca' 'Plot' 'Detached Villa' 'Semi-detached'
#  'Penthouse' 'Town House' 'Detached' 'Warehouse' 'Commercial Property'
#  'Land' 'Guest House' 'Hospitality' 'Commercial Development' 'Shop'
#  'Property' 'Bar / Nightclub' 'Equestrian Facility' 'Restaurant' 'Office'
#  'Sheltered Housing' 'Bungalow' 'House' 'Farm' 'Ground Flat' 'Parking'
#  'Garage' 'Cafe' 'Storage' 'Studio' 'Duplex' 'Cave House']
#            price  bedrooms  bathrooms  indoor surface area in sqm  \
# count     12,086    12,084     10,952                      10,414
# mean   1,046,977     2,534      1,076                         233
# std    1,881,298    98,531     46,365                         265
# min        4,500         0          0                          10
# 25%      285,000         2          2                         100
# 50%      475,000         3          2                         144
# 75%      995,000         5          4                         269
# max   50,000,000 9,700,000  4,630,000                       5,367
#
#        outdoor surface area in sqm      y
# count                        3,821 12,086
# mean                        11,132     13
# std                        196,065      1
# min                              1      8
# 25%                            401     13
# 50%                          1,009     13
# 75%                          2,342     14
# max                      9,350,000     18

# %%
non_residential = {
    'Plot', 'Land', 'Commercial Property', 'Commercial Development',
    'Warehouse', 'Shop', 'Office', 'Restaurant', 'Bar / Nightclub',
    'Cafe', 'Parking', 'Garage', 'Storage', 'Property', 'Other'
}

df.loc[df['property_type'].isin(non_residential), 'bedrooms'] = np.nan
df.loc[df['property_type'].isin(non_residential), 'bathrooms'] = np.nan
df.head()
# Out:
#   reference                        location     price  \
# 0   R126116  Nueva Andalucía, Costa del Sol   450,000
# 1   R132516     Puerto Banús, Costa del Sol 1,250,000
# 2   R121563        Antequera, Costa del Sol   749,000
# 3   R127293       La Mairena, Costa del Sol   500,000
# 4   R114041      Benalmadena, Costa del Sol 1,695,000
#
#                       title  bedrooms  bathrooms  indoor surface area in sqm  \
# 0       3 Bedroom Apartment         3          2                         120
# 1                     Other       NaN        NaN                         NaN
# 2          12 Bedroom Finca        12          7                         366
# 3                      Plot       NaN        NaN                         NaN
# 4  4 Bedroom Detached Villa         4          4                         634
#
#    outdoor surface area in sqm  \
# 0                          NaN
# 1                          NaN
# 2                        5,353
# 3                          NaN
# 4                        1,000
#
#        pipe-separed list of features of the property  \
# 0  Close to Shops|Electricity Utilities|Close to ...
# 1  Electricity Utilities|Close to Town|Street Vie...
# 2  Mountain Views|Private Garden|Open Parking|Urb...
# 3  Mountain Views|Private Garden|Electricity Util...
# 4  Private Garden|Electricity Utilities|Drinkable...
#
#                                             features   property_type  y
# 0  [close to shops, electricity utilities, close ...       Apartment 13
# 1  [electricity utilities, close to town, street ...           Other 14
# 2  [mountain views, private garden, open parking,...           Finca 14
# 3  [mountain views, private garden, electricity u...            Plot 13
# 4  [private garden, electricity utilities, drinka...  Detached Villa 14

# %%
df['location'] = df['location'].str.strip()
df[['city', 'region']] = df['location'].str.split(',', n=1, expand=True)
df['city'] = df['city'].str.strip()
df['region'] = df['region'].str.strip()

df['city'].nunique()
# Out:
# 226

# %%
train_df, test_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42
)

# %%
tr, val = train_test_split(
    train_df,
    test_size=0.2,
    random_state=42
)

limit = {}
for col in ['price', 'indoor surface area in sqm', 'outdoor surface area in sqm']:
    limit[col] = tr[col].quantile(0.995)

limit['bedrooms'] = tr['bedrooms'].quantile(0.99)
limit['bathrooms'] = tr['bathrooms'].quantile(0.99)

def apply_caps(df, limit):
    df = df.copy()
    for col, cap in limit.items():
        df[col] = df[col].clip(upper=cap)
    return df

tr = apply_caps(tr, limit)
val = apply_caps(val, limit)
test_df = apply_caps(test_df, limit)

# %%
global_mean = tr['y'].mean()

city_stats = (
    tr.groupby('city')['y']
    .agg(['mean', 'count'])
)

k = 20
city_stats['mean'] = (
    (city_stats['count'] * city_stats['mean'] + k * global_mean) /
    (city_stats['count'] + k)
)

def add_city_mean(df):
    return df.assign(
        city_mean=df['city'].map(city_stats['mean']).fillna(global_mean)
    )

tr = add_city_mean(tr)
val = add_city_mean(val)
test_df = add_city_mean(test_df)

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
ohe.fit(tr[['property_type']])

ohe_cols = ohe.get_feature_names_out(['property_type'])

def apply_ohe(df):
    ohe_arr = ohe.transform(df[['property_type']])
    df[ohe_cols] = ohe_arr
    return df

tr = apply_ohe(tr)
val = apply_ohe(val)
test_df = apply_ohe(test_df)

# %%
#df['features'] = df['pipe-separed list of features of the property'].str.split('|')

counts = Counter(tr["features"].explode().str.strip())
top_10 = counts.most_common(30)
top_10.append(("Other", 1))
d = dict(top_10)
names = list(d.keys())
names
# Out:
# ['fully fitted kitchen',
#  'private terrace',
#  'air conditioning climate control',
#  'fitted wardrobes',
#  'close to shops',
#  'covered terrace',
#  'electricity utilities',
#  'close to schools',
#  'excellent condition',
#  'communal pool',
#  'south orientation',
#  'sea views',
#  'mountain views',
#  'urbanisation',
#  'ensuite bathroom',
#  'close to sea',
#  'communal garden',
#  'gated complex security',
#  'near transport',
#  'garden views',
#  'double glazing',
#  'drinkable water utilities',
#  'close to town',
#  'storage room',
#  'resale',
#  'lift',
#  'close to golf',
#  'investment',
#  'panoramic views',
#  'private parking',
#  'Other']

# %%
def add_feature_cols(df, features):
    for f in features:
        df[f] = df['features'].apply(
            lambda x: int(f in x) if isinstance(x, str) else 0
        )
    return df

tr = add_feature_cols(tr, names)
val = add_feature_cols(val, names)
test_df = add_feature_cols(test_df, names)

# %%
tr['price_log'] = np.log1p(tr['price'])
val['price_log'] = np.log1p(val['price'])

for col in ['indoor surface area in sqm', 'outdoor surface area in sqm']:
    tr[f'{col}_log'] = np.log1p(tr[col])
    val[f'{col}_log'] = np.log1p(val[col])
    test_df[f'{col}_log'] = np.log1p(test_df[col])

y_tr = tr['price_log']
y_val = val['price_log']

X_tr = tr.drop(columns=['price', 'price_log'])
X_val = val.drop(columns=['price', 'price_log'])

# %%
feature_cols = (['city_mean', 'bedrooms', 'bathrooms','indoor surface area in sqm',
     'outdoor surface area in sqm'] + names + list(ohe_cols))

X_tr = tr[feature_cols]
X_val = val[feature_cols]
X_test = test_df[feature_cols]

# %%
X_tr.info()
print()
X_tr.tail()
#for col in df.select_dtypes(include=['object']).columns:
#    print(f"Unique values in {col}: {df[col].nunique()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7734 entries, 9102 to 9047
# Data columns (total 68 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   city_mean                             7734 non-null   float64
#  1   bedrooms                              6694 non-null   float64
#  2   bathrooms                             6681 non-null   float64
#  3   indoor surface area in sqm            6641 non-null   float64
#  4   outdoor surface area in sqm           2429 non-null   float64
#  5   fully fitted kitchen                  7734 non-null   int64
#  6   private terrace                       7734 non-null   int64
#  7   air conditioning climate control      7734 non-null   int64
#  8   fitted wardrobes                      7734 non-null   int64
#  9   close to shops                        7734 non-null   int64
#  10  covered terrace                       7734 non-null   int64
#  11  electricity utilities                 7734 non-null   int64
#  12  close to schools                      7734 non-null   int64
#  13  excellent condition                   7734 non-null   int64
#  14  communal pool                         7734 non-null   int64
#  15  south orientation                     7734 non-null   int64
#  16  sea views                             7734 non-null   int64
#  17  mountain views                        7734 non-null   int64
#  18  urbanisation                          7734 non-null   int64
#  19  ensuite bathroom                      7734 non-null   int64
#  20  close to sea                          7734 non-null   int64
#  21  communal garden                       7734 non-null   int64
#  22  gated complex security                7734 non-null   int64
#  23  near transport                        7734 non-null   int64
#  24  garden views                          7734 non-null   int64
#  25  double glazing                        7734 non-null   int64
#  26  drinkable water utilities             7734 non-null   int64
#  27  close to town                         7734 non-null   int64
#  28  storage room                          7734 non-null   int64
#  29  resale                                7734 non-null   int64
#  30  lift                                  7734 non-null   int64
#  31  close to golf                         7734 non-null   int64
#  32  investment                            7734 non-null   int64
#  33  panoramic views                       7734 non-null   int64
#  34  private parking                       7734 non-null   int64
#  35  Other                                 7734 non-null   int64
#  36  property_type_Apartment               7734 non-null   float64
#  37  property_type_Bar / Nightclub         7734 non-null   float64
#  38  property_type_Bungalow                7734 non-null   float64
#  39  property_type_Cafe                    7734 non-null   float64
#  40  property_type_Commercial Development  7734 non-null   float64
#  41  property_type_Commercial Property     7734 non-null   float64
#  42  property_type_Detached                7734 non-null   float64
#  43  property_type_Detached Villa          7734 non-null   float64
#  44  property_type_Duplex                  7734 non-null   float64
#  45  property_type_Equestrian Facility     7734 non-null   float64
#  46  property_type_Farm                    7734 non-null   float64
#  47  property_type_Finca                   7734 non-null   float64
#  48  property_type_Garage                  7734 non-null   float64
#  49  property_type_Ground Flat             7734 non-null   float64
#  50  property_type_Guest House             7734 non-null   float64
#  51  property_type_Hospitality             7734 non-null   float64
#  52  property_type_House                   7734 non-null   float64
#  53  property_type_Land                    7734 non-null   float64
#  54  property_type_Office                  7734 non-null   float64
#  55  property_type_Other                   7734 non-null   float64
#  56  property_type_Parking                 7734 non-null   float64
#  57  property_type_Penthouse               7734 non-null   float64
#  58  property_type_Plot                    7734 non-null   float64
#  59  property_type_Property                7734 non-null   float64
#  60  property_type_Restaurant              7734 non-null   float64
#  61  property_type_Semi-detached           7734 non-null   float64
#  62  property_type_Sheltered Housing       7734 non-null   float64
#  63  property_type_Shop                    7734 non-null   float64
#  64  property_type_Storage                 7734 non-null   float64
#  65  property_type_Studio                  7734 non-null   float64
#  66  property_type_Town House              7734 non-null   float64
#  67  property_type_Warehouse               7734 non-null   float64
# dtypes: float64(37), int64(31)
# memory usage: 4.1 MB
#       city_mean  bedrooms  bathrooms  indoor surface area in sqm  \
# 9913         13         2          2                          94
# 3875         13         3          3                         189
# 2934         13         3          2                         145
# 6759         14         6          7                         987
# 9047         13         2          2                         168
#
#       outdoor surface area in sqm  fully fitted kitchen  private terrace  \
# 9913                          NaN                     0                0
# 3875                          NaN                     0                0
# 2934                          NaN                     0                0
# 6759                        1,871                     0                0
# 9047                          NaN                     0                0
#
#       air conditioning climate control  fitted wardrobes  close to shops  ...  \
# 9913                                 0                 0               0  ...
# 3875                                 0                 0               0  ...
# 2934                                 0                 0               0  ...
# 6759                                 0                 0               0  ...
# 9047                                 0                 0               0  ...
#
#       property_type_Plot  property_type_Property  property_type_Restaurant  \
# 9913                   0                       0                         0
# 3875                   0                       0                         0
# 2934                   0                       0                         0
# 6759                   0                       0                         0
# 9047                   0                       0                         0
#
#       property_type_Semi-detached  property_type_Sheltered Housing  \
# 9913                            0                                0
# 3875                            0                                0
# 2934                            0                                0
# 6759                            0                                0
# 9047                            0                                0
#
#       property_type_Shop  property_type_Storage  property_type_Studio  \
# 9913                   0                      0                     0
# 3875                   0                      0                     0
# 2934                   0                      0                     0
# 6759                   0                      0                     0
# 9047                   0                      0                     0
#
#       property_type_Town House  property_type_Warehouse
# 9913                         0                        0
# 3875                         0                        0
# 2934                         1                        0
# 6759                         0                        0
# 9047                         0                        0
#
# [5 rows x 68 columns]

# %%
X_tr.columns
# Out:
# Index(['city_mean', 'bedrooms', 'bathrooms', 'indoor surface area in sqm',
#        'outdoor surface area in sqm', 'fully fitted kitchen',
#        'private terrace', 'air conditioning climate control',
#        'fitted wardrobes', 'close to shops', 'covered terrace',
#        'electricity utilities', 'close to schools', 'excellent condition',
#        'communal pool', 'south orientation', 'sea views', 'mountain views',
#        'urbanisation', 'ensuite bathroom', 'close to sea', 'communal garden',
#        'gated complex security', 'near transport', 'garden views',
#        'double glazing', 'drinkable water utilities', 'close to town',
#        'storage room', 'resale', 'lift', 'close to golf', 'investment',
#        'panoramic views', 'private parking', 'Other',
#        'property_type_Apartment', 'property_type_Bar / Nightclub',
#        'property_type_Bungalow', 'property_type_Cafe',
#        'property_type_Commercial Development',
#        'property_type_Commercial Property', 'property_type_Detached',
#        'property_type_Detached Villa', 'property_type_Duplex',
#        'property_type_Equestrian Facility', 'property_type_Farm',
#        'property_type_Finca', 'property_type_Garage',
#        'property_type_Ground Flat', 'property_type_Guest House',
#        'property_type_Hospitality', 'property_type_House',
#        'property_type_Land', 'property_type_Office', 'property_type_Other',
#        'property_type_Parking', 'property_type_Penthouse',
#        'property_type_Plot', 'property_type_Property',
#        'property_type_Restaurant', 'property_type_Semi-detached',
#        'property_type_Sheltered Housing', 'property_type_Shop',
#        'property_type_Storage', 'property_type_Studio',
#        'property_type_Town House', 'property_type_Warehouse'],
#       dtype='object')

# %%
import sys
print(sys.path)
# Out:
# ['/Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP', '/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev', '/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/jupyter_debug', '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python39.zip', '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9', '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/lib-dynload', '', '/Users/linas.danusevicius/Library/Python/3.9/lib/python/site-packages', '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages']

# %%
import preproc
# Out:
# /Users/linas.danusevicius/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# LOADED preproc.py
# cpu

# %%
import preproc

preproc.encode_descriptions()
# Out:
# Batches:   0%|          | 0/378 [00:00<?, ?it/s]
# (      reference                        location       price  \
#  0       R126116  Nueva Andalucía, Costa del Sol    €450,000
#  1       R132516     Puerto Banús, Costa del Sol  €1,250,000
#  2       R121563        Antequera, Costa del Sol    €749,000
#  3       R127293       La Mairena, Costa del Sol    €500,000
#  4       R114041      Benalmadena, Costa del Sol  €1,695,000
#  ...         ...                             ...         ...
#  12081    R89338      Mijas Costa, Costa del Sol  €3,500,000
#  12082   R823240        Costalita, Costa del Sol  €1,400,000
#  12083    R90252  Guadalmina Alta, Costa del Sol  €1,015,000
#  12084    R89424        La Quinta, Costa del Sol    €395,000
#  12085   R706006         Cabopino, Costa del Sol  €1,750,000
#
#                            title   bedrooms   bathrooms  \
#  0           3 Bedroom Apartment          3           2
#  1                         Other          1         504
#  2              12 Bedroom Finca         12           7
#  3                          Plot      3,470         NaN
#  4      4 Bedroom Detached Villa          4           4
#  ...                         ...        ...         ...
#  12081          1 Detached Villa         10          10
#  12082       3 Bedroom Apartment          3           3
#  12083      7 Bedroom Town House          7           6
#  12084       2 Bedroom Apartment          2           2
#  12085  4 Bedroom Detached Villa          4           4
#
#          indoor surface area in sqm   outdoor surface area in sqm  \
#  0                              120                           NaN
#  1                              NaN                           NaN
#  2                              366                         5,353
#  3                              NaN                           NaN
#  4                              634                         1,000
#  ...                            ...                           ...
#  12081                        1,200                        10,000
#  12082                          200                           NaN
#  12083                          620                           500
#  12084                          100                           NaN
#  12085                          300                           407
#
#             pipe-separed list of features of the property  \
#  0      Close to Shops|Electricity Utilities|Close to ...
#  1      Electricity Utilities|Close to Town|Street Vie...
#  2      Mountain Views|Private Garden|Open Parking|Urb...
#  3      Mountain Views|Private Garden|Electricity Util...
#  4      Private Garden|Electricity Utilities|Drinkable...
#  ...                                                  ...
#  12081  Mountain Views|Private Garden|Electricity Util...
#  12082  Private Parking|South Orientation|Fully Fitted...
#  12083  Mountain Views|Country Views|Close to Town|Pri...
#  12084  Electricity Utilities|Urbanisation|Street Park...
#  12085  Close to Shops|Private Garden|Private Pool|Sou...
#
#                                               description
#  0      Apartment - Middle Floor, Nueva Andalucía, Cos...
#  1      Commercial permises of 504sqm in Centro Puerta...
#  2      Reduced €451,000! Originally listed for €1,200...
#  3      Magnificent plot with a beautiful view in a pi...
#  4      A fantastic luxury villa with sea views, just ...
#  ...                                                  ...
#  12081  Unique opportunity to buy a typical Andalusian...
#  12082  This luxury apartment is situated in Costalita...
#  12083  GUADALMINA ALTA. Luxury villa, second line gol...
#  12084  RECENTLY FULLY REFORMED\nThis south-west facin...
#  12085  This semi detached villa with 4 bedrooms and 3...
#
#  [12086 rows x 10 columns],
#  array([[-0.01997116, -0.02660568, -0.02316256, ..., -0.00662326,
#          -0.02707089, -0.01383808],
#         [-0.03052843,  0.01120769, -0.00557717, ..., -0.01513271,
#          -0.02965901, -0.00935289],
#         [-0.02865477, -0.02919858, -0.0139556 , ...,  0.00355443,
#           0.01100034, -0.02656401],
#         ...,
#         [-0.00197259,  0.02141818, -0.01555736, ...,  0.02364032,
#          -0.00098498, -0.00061359],
#         [-0.04664101, -0.045945  , -0.0034088 , ..., -0.00419933,
#          -0.01172949,  0.02287332],
#         [-0.04208362,  0.00202755, -0.00300222, ...,  0.01055716,
#          -0.00430073, -0.00119395]], dtype=float32))

# %%
preproc.encode_images()
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Encoding images: 100%|██████████| 12086/12086 [33:35<00:00,  6.00it/s]
# (      reference                        location       price  \
#  0       R126116  Nueva Andalucía, Costa del Sol    €450,000
#  1       R132516     Puerto Banús, Costa del Sol  €1,250,000
#  2       R121563        Antequera, Costa del Sol    €749,000
#  3       R127293       La Mairena, Costa del Sol    €500,000
#  4       R114041      Benalmadena, Costa del Sol  €1,695,000
#  ...         ...                             ...         ...
#  12081    R89338      Mijas Costa, Costa del Sol  €3,500,000
#  12082   R823240        Costalita, Costa del Sol  €1,400,000
#  12083    R90252  Guadalmina Alta, Costa del Sol  €1,015,000
#  12084    R89424        La Quinta, Costa del Sol    €395,000
#  12085   R706006         Cabopino, Costa del Sol  €1,750,000
#
#                            title   bedrooms   bathrooms  \
#  0           3 Bedroom Apartment          3           2
#  1                         Other          1         504
#  2              12 Bedroom Finca         12           7
#  3                          Plot      3,470         NaN
#  4      4 Bedroom Detached Villa          4           4
#  ...                         ...        ...         ...
#  12081          1 Detached Villa         10          10
#  12082       3 Bedroom Apartment          3           3
#  12083      7 Bedroom Town House          7           6
#  12084       2 Bedroom Apartment          2           2
#  12085  4 Bedroom Detached Villa          4           4
#
#          indoor surface area in sqm   outdoor surface area in sqm  \
#  0                              120                           NaN
#  1                              NaN                           NaN
#  2                              366                         5,353
#  3                              NaN                           NaN
#  4                              634                         1,000
#  ...                            ...                           ...
#  12081                        1,200                        10,000
#  12082                          200                           NaN
#  12083                          620                           500
#  12084                          100                           NaN
#  12085                          300                           407
#
#             pipe-separed list of features of the property
#  0      Close to Shops|Electricity Utilities|Close to ...
#  1      Electricity Utilities|Close to Town|Street Vie...
#  2      Mountain Views|Private Garden|Open Parking|Urb...
#  3      Mountain Views|Private Garden|Electricity Util...
#  4      Private Garden|Electricity Utilities|Drinkable...
#  ...                                                  ...
#  12081  Mountain Views|Private Garden|Electricity Util...
#  12082  Private Parking|South Orientation|Fully Fitted...
#  12083  Mountain Views|Country Views|Close to Town|Pri...
#  12084  Electricity Utilities|Urbanisation|Street Park...
#  12085  Close to Shops|Private Garden|Private Pool|Sou...
#
#  [12086 rows x 9 columns],
#  array([[-0.01865991,  0.01751625,  0.00134096, ...,  0.06639036,
#           0.00658441, -0.00329242],
#         [-0.01504618, -0.00499658,  0.00030586, ...,  0.04321935,
#          -0.00025826, -0.03026018],
#         [-0.0039148 ,  0.01934739, -0.00292152, ...,  0.05141163,
#           0.000313  , -0.0134353 ],
#         ...,
#         [-0.0185862 ,  0.03001707, -0.00042668, ...,  0.10272213,
#           0.00501778, -0.00707226],
#         [-0.00939176,  0.01853941, -0.00057144, ...,  0.05060467,
#           0.00410062, -0.01072133],
#         [-0.01611793,  0.02769277, -0.00065185, ...,  0.09515252,
#           0.00256519, -0.00729487]]))

# %%
X_tr, y_tr, X_val, y_val, X_test, feature_cols = preproc.get_preprocessed_data()
print(X_tr.shape, y_tr.shape, X_val.shape, y_val.shape, X_test.shape)
print(feature_cols[:10])
# Out:
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# ...
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# /Users/linas.danusevicius/Desktop/University/4_Machine Learning Algorithms 1/IP/Real-Estate-Southern-Spain-2024/models/preproc.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_[cols] = emb
# (7734, 1345) (7734,) (1934, 1345) (1934,) (2418, 1345)
# ['city_mean', 'bedrooms', 'bathrooms', 'fully fitted kitchen', 'private terrace', 'air conditioning climate control', 'fitted wardrobes', 'close to shops', 'covered terrace', 'electricity utilities']
